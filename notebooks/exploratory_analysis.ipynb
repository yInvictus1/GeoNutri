# %% [markdown]
# # Análise Exploratória de Dados - Desertos Alimentares RJ
#
# Este notebook contém a análise inicial dos dados do IBGE e OpenStreetMap para identificar desertos alimentares no Rio de Janeiro.
